# %%
import json
import nltk
from nltk.tokenize import sent_tokenize

# Ensure NLTK tokenizers are downloaded
nltk.download('punkt')

def process_line_by_line(dataset_file, hate_sents_file, retain_file):
    """Process large files line by line to handle big data efficiently."""
    
    # Load hate_sents into memory, since it's likely much smaller than the dataset
    with open(hate_sents_file, 'r', encoding='utf-8') as f:
        hate_sents = [json.loads(line) for line in f]
    
    # Convert hate_sents into a dictionary for quick lookup
    hate_sents_dict = {entry['year']: set(entry['text']) for entry in hate_sents}

    # Open the retain set output file
    with open(retain_file, 'w', encoding='utf-8') as retain_out:
        # Process the dataset file line by line
        with open(dataset_file, 'r', encoding='utf-8') as dataset_in:
            for line in dataset_in:
                entry = json.loads(line)
                year = entry['year']
                text = entry['text']
                
                # Tokenize the text into sentences
                sentences = sent_tokenize(text)

                # If there are hateful sentences for this year, remove them
                if year in hate_sents_dict:
                    hateful_sentences = hate_sents_dict[year]
                    # Remove sentences that are in the hateful set
                    retain_sentences = [sent for sent in sentences if sent not in hateful_sentences]
                else:
                    retain_sentences = sentences

                # Join sentences back into a single block of text
                # retain_text = ' '.join(retain_sentences)
                retain_text = retain_sentences
                print(f"Year: {year}: {len(retain_text)} not marked as hateful sentences remaining")
                
                # Write the cleaned entry to the retain set file
                retain_out.write(json.dumps({'year': year, 'text': retain_text}) + '\n')

    print(f'Retain set saved to {retain_file}')
    
threshold = 0.7

# Adjust to your file structure
# Paths
dataset_file = TODO
hate_sents_file = f'{TODO}/pg_books_hate_set_{str(threshold).replace(".", "_")}.jsonl'
retain_file = f'{TODO}/pg_books_retain_set_{str(threshold).replace(".", "_")}.jsonl'

# Execute
process_line_by_line(dataset_file, hate_sents_file, retain_file)
# Out:
# [nltk_data] Downloading package punkt to /home/ljf/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Year: 1979: 14288 not marked as hateful sentences remaining
# Year: 1753: 43504 not marked as hateful sentences remaining
# Year: 1789: 63255 not marked as hateful sentences remaining
# Year: 1779: 13276 not marked as hateful sentences remaining
# Year: 1844: 208423 not marked as hateful sentences remaining
# Year: 1809: 22781 not marked as hateful sentences remaining
# Year: 1842: 196702 not marked as hateful sentences remaining
# Year: 1926: 331321 not marked as hateful sentences remaining
# Year: 1783: 18417 not marked as hateful sentences remaining
# Year: 1923: 1158715 not marked as hateful sentences remaining
# Year: 1989: 504 not marked as hateful sentences remaining
# Year: 1903: 1336036 not marked as hateful sentences remaining
# Year: 1765: 13497 not marked as hateful sentences remaining
# Year: 1937: 40097 not marked as hateful sentences remaining
# Year: 1851: 401448 not marked as hateful sentences remaining
# Year: 1816: 46580 not marked as hateful sentences remaining
# Year: 1803: 29428 not marked as hateful sentences remaining
# Year: 1981: 8455 not marked as hateful sentences remaining
# Year: 1774: 13443 not marked as hateful sentences remaining
# Year: 1966: 6901 not marked as hateful sentences remaining
# Year: 1939: 75217 not marked as hateful sentences remaining
# Year: 1965: 18104 not marked as hateful sentences remaining
# Year: 1813: 32903 not marked as hateful sentences remaining
# Year: 1793: 18634 not marked as hateful sentences remaining
# Year: 1861: 395871 not marked as hateful sentences remaining
# Year: 1948: 57557 not marked as hateful sentences remaining
# Year: 1889: 834175 not marked as hateful sentences remaining
# Year: 1882: 529975 not marked as hateful sentences remaining
# Year: 1825: 82280 not marked as hateful sentences remaining
# Year: 1970: 27903 not marked as hateful sentences remaining
# Year: 1927: 167527 not marked as hateful sentences remaining
# Year: 1835: 91232 not marked as hateful sentences remaining
# Year: 1896: 1079291 not marked as hateful sentences remaining
# Year: 1828: 41781 not marked as hateful sentences remaining
# Year: 1863: 372411 not marked as hateful sentences remaining
# Year: 1885: 561957 not marked as hateful sentences remaining
# Year: 1755: 505 not marked as hateful sentences remaining
# Year: 1852: 252355 not marked as hateful sentences remaining
# Year: 1931: 84839 not marked as hateful sentences remaining
# Year: 1814: 44074 not marked as hateful sentences remaining
# Year: 1791: 45003 not marked as hateful sentences remaining
# Year: 1848: 318599 not marked as hateful sentences remaining
# Year: 1794: 66061 not marked as hateful sentences remaining
# Year: 1843: 295477 not marked as hateful sentences remaining
# Year: 1772: 13043 not marked as hateful sentences remaining
# Year: 1925: 436824 not marked as hateful sentences remaining
# Year: 1975: 10185 not marked as hateful sentences remaining
# Year: 1996: 3696 not marked as hateful sentences remaining
# Year: 2000: 3255 not marked as hateful sentences remaining
# Year: 1902: 1328425 not marked as hateful sentences remaining
# Year: 1985: 1966 not marked as hateful sentences remaining
# Year: 1775: 25492 not marked as hateful sentences remaining
# Year: 1988: 1530 not marked as hateful sentences remaining
# Year: 1834: 117318 not marked as hateful sentences remaining
# Year: 1776: 210841 not marked as hateful sentences remaining
# Year: 1877: 461958 not marked as hateful sentences remaining
# Year: 1906: 1783577 not marked as hateful sentences remaining
# Year: 1894: 1088576 not marked as hateful sentences remaining
# Year: 1930: 116675 not marked as hateful sentences remaining
# Year: 1993: 1933 not marked as hateful sentences remaining
# Year: 1887: 773591 not marked as hateful sentences remaining
# Year: 1911: 2024609 not marked as hateful sentences remaining
# Year: 1855: 278269 not marked as hateful sentences remaining
# Year: 1787: 33607 not marked as hateful sentences remaining
# Year: 1760: 5679 not marked as hateful sentences remaining
# Year: 1969: 13284 not marked as hateful sentences remaining
# Year: 1928: 152734 not marked as hateful sentences remaining
# Year: 1754: 4430 not marked as hateful sentences remaining
# Year: 1799: 35200 not marked as hateful sentences remaining
# Year: 1909: 1776588 not marked as hateful sentences remaining
# Year: 1838: 153190 not marked as hateful sentences remaining
# Year: 1841: 167444 not marked as hateful sentences remaining
# Year: 1810: 25865 not marked as hateful sentences remaining
# Year: 1884: 698704 not marked as hateful sentences remaining
# Year: 1971: 12497 not marked as hateful sentences remaining
# Year: 1924: 727604 not marked as hateful sentences remaining
# Year: 1932: 59408 not marked as hateful sentences remaining
# Year: 1827: 54081 not marked as hateful sentences remaining
# Year: 1907: 1646919 not marked as hateful sentences remaining
# Year: 1964: 28025 not marked as hateful sentences remaining
# Year: 1897: 1228050 not marked as hateful sentences remaining
# Year: 1767: 5375 not marked as hateful sentences remaining
# Year: 1880: 1003670 not marked as hateful sentences remaining
# Year: 1833: 74918 not marked as hateful sentences remaining
# Year: 1987: 1278 not marked as hateful sentences remaining
# Year: 1800: 851862 not marked as hateful sentences remaining
# Year: 1784: 12958 not marked as hateful sentences remaining
# Year: 1943: 59473 not marked as hateful sentences remaining
# Year: 1888: 797857 not marked as hateful sentences remaining
# Year: 1768: 48884 not marked as hateful sentences remaining
# Year: 1872: 601878 not marked as hateful sentences remaining
# Year: 1780: 7579 not marked as hateful sentences remaining
# Year: 1807: 67154 not marked as hateful sentences remaining
# Year: 1899: 1494684 not marked as hateful sentences remaining
# Year: 1854: 259786 not marked as hateful sentences remaining
# Year: 1891: 859397 not marked as hateful sentences remaining
# Year: 1960: 89986 not marked as hateful sentences remaining
# Year: 1962: 95190 not marked as hateful sentences remaining
# Year: 1756: 7442 not marked as hateful sentences remaining
# Year: 1860: 437081 not marked as hateful sentences remaining
# Year: 1762: 23981 not marked as hateful sentences remaining
# Year: 1919: 1844658 not marked as hateful sentences remaining
# Year: 1879: 486962 not marked as hateful sentences remaining
# Year: 1952: 39956 not marked as hateful sentences remaining
# Year: 1777: 7091 not marked as hateful sentences remaining
# Year: 1847: 289892 not marked as hateful sentences remaining
# Year: 1815: 72195 not marked as hateful sentences remaining
# Year: 1986: 4945 not marked as hateful sentences remaining
# Year: 1764: 5674 not marked as hateful sentences remaining
# Year: 1846: 278516 not marked as hateful sentences remaining
# Year: 1821: 45424 not marked as hateful sentences remaining
# Year: 1972: 6954 not marked as hateful sentences remaining
# Year: 1868: 486873 not marked as hateful sentences remaining
# Year: 1874: 434093 not marked as hateful sentences remaining
# Year: 1771: 10266 not marked as hateful sentences remaining
# Year: 1804: 41623 not marked as hateful sentences remaining
# Year: 1980: 5260 not marked as hateful sentences remaining
# Year: 1865: 520335 not marked as hateful sentences remaining
# Year: 1940: 58257 not marked as hateful sentences remaining
# Year: 1871: 824617 not marked as hateful sentences remaining
# Year: 1953: 94209 not marked as hateful sentences remaining
# Year: 1946: 63667 not marked as hateful sentences remaining
# Year: 1914: 2228615 not marked as hateful sentences remaining
# Year: 1959: 51310 not marked as hateful sentences remaining
# Year: 1836: 170911 not marked as hateful sentences remaining
# Year: 1944: 74595 not marked as hateful sentences remaining
# Year: 1956: 68960 not marked as hateful sentences remaining
# Year: 1942: 55876 not marked as hateful sentences remaining
# Year: 1921: 2025245 not marked as hateful sentences remaining
# Year: 1918: 1769514 not marked as hateful sentences remaining
# Year: 1920: 2292454 not marked as hateful sentences remaining
# Year: 1973: 13888 not marked as hateful sentences remaining
# Year: 1819: 76183 not marked as hateful sentences remaining
# Year: 1801: 38796 not marked as hateful sentences remaining
# Year: 1991: 435 not marked as hateful sentences remaining
# Year: 1839: 241978 not marked as hateful sentences remaining
# Year: 1792: 28243 not marked as hateful sentences remaining
# Year: 1870: 583768 not marked as hateful sentences remaining
# Year: 1941: 65161 not marked as hateful sentences remaining
# Year: 1938: 87240 not marked as hateful sentences remaining
# Year: 1857: 431589 not marked as hateful sentences remaining
# Year: 1830: 163779 not marked as hateful sentences remaining
# Year: 1752: 1220 not marked as hateful sentences remaining
# Year: 1820: 77774 not marked as hateful sentences remaining
# Year: 1913: 2260081 not marked as hateful sentences remaining
# Year: 1929: 96751 not marked as hateful sentences remaining
# Year: 1849: 197133 not marked as hateful sentences remaining
# Year: 1869: 492828 not marked as hateful sentences remaining
# Year: 1781: 16950 not marked as hateful sentences remaining
# Year: 1790: 22338 not marked as hateful sentences remaining
# Year: 1900: 2293988 not marked as hateful sentences remaining
# Year: 1853: 407464 not marked as hateful sentences remaining
# Year: 1905: 1592791 not marked as hateful sentences remaining
# Year: 1785: 12272 not marked as hateful sentences remaining
# Year: 1808: 23678 not marked as hateful sentences remaining
# Year: 1832: 131542 not marked as hateful sentences remaining
# Year: 1795: 14077 not marked as hateful sentences remaining
# Year: 1859: 421907 not marked as hateful sentences remaining
# Year: 1805: 49610 not marked as hateful sentences remaining
# Year: 1916: 1925344 not marked as hateful sentences remaining
# Year: 1829: 68317 not marked as hateful sentences remaining
# Year: 1802: 18935 not marked as hateful sentences remaining
# Year: 1951: 50415 not marked as hateful sentences remaining
# Year: 1773: 18524 not marked as hateful sentences remaining
# Year: 1858: 366479 not marked as hateful sentences remaining
# Year: 1895: 1160535 not marked as hateful sentences remaining
# Year: 1995: 920 not marked as hateful sentences remaining
# Year: 1778: 9943 not marked as hateful sentences remaining
# Year: 1750: 6475 not marked as hateful sentences remaining
# Year: 1958: 82710 not marked as hateful sentences remaining
# Year: 1915: 2020217 not marked as hateful sentences remaining
# Year: 1974: 6006 not marked as hateful sentences remaining
# Year: 1950: 76782 not marked as hateful sentences remaining
# Year: 1935: 72541 not marked as hateful sentences remaining
# Year: 1893: 985477 not marked as hateful sentences remaining
# Year: 1936: 55587 not marked as hateful sentences remaining
# Year: 1999: 2024 not marked as hateful sentences remaining
# Year: 1954: 46189 not marked as hateful sentences remaining
# Year: 1751: 23708 not marked as hateful sentences remaining
# Year: 1763: 630 not marked as hateful sentences remaining
# Year: 1831: 94849 not marked as hateful sentences remaining
# Year: 1873: 532026 not marked as hateful sentences remaining
# Year: 1910: 2112388 not marked as hateful sentences remaining
# Year: 1770: 3334 not marked as hateful sentences remaining
# Year: 1782: 24725 not marked as hateful sentences remaining
# Year: 1976: 8973 not marked as hateful sentences remaining
# Year: 1875: 546941 not marked as hateful sentences remaining
# Year: 1817: 80936 not marked as hateful sentences remaining
# Year: 1997: 6036 not marked as hateful sentences remaining
# Year: 1963: 99295 not marked as hateful sentences remaining
# Year: 1867: 390890 not marked as hateful sentences remaining
# Year: 1908: 1728817 not marked as hateful sentences remaining
# Year: 1798: 19616 not marked as hateful sentences remaining
# Year: 1977: 2353 not marked as hateful sentences remaining
# Year: 1878: 462808 not marked as hateful sentences remaining
# Year: 1840: 216449 not marked as hateful sentences remaining
# Year: 1967: 8409 not marked as hateful sentences remaining
# Year: 1983: 581 not marked as hateful sentences remaining
# Year: 1945: 37968 not marked as hateful sentences remaining
# Year: 1912: 2058128 not marked as hateful sentences remaining
# Year: 1947: 60029 not marked as hateful sentences remaining
# Year: 1823: 72003 not marked as hateful sentences remaining
# Year: 1824: 62786 not marked as hateful sentences remaining
# Year: 1856: 479598 not marked as hateful sentences remaining
# Year: 1904: 1503275 not marked as hateful sentences remaining
# Year: 1968: 13840 not marked as hateful sentences remaining
# Year: 1892: 1079843 not marked as hateful sentences remaining
# Year: 1898: 1409273 not marked as hateful sentences remaining
# Year: 1955: 84673 not marked as hateful sentences remaining
# Year: 1837: 216324 not marked as hateful sentences remaining
# Year: 1886: 744675 not marked as hateful sentences remaining
# Year: 1826: 52831 not marked as hateful sentences remaining
# Year: 1949: 71890 not marked as hateful sentences remaining
# Year: 1881: 566148 not marked as hateful sentences remaining
# Year: 1901: 1319504 not marked as hateful sentences remaining
# Year: 1957: 68258 not marked as hateful sentences remaining
# Year: 1766: 17643 not marked as hateful sentences remaining
# Year: 1864: 397002 not marked as hateful sentences remaining
# Year: 1811: 19835 not marked as hateful sentences remaining
# Year: 1862: 332957 not marked as hateful sentences remaining
# Year: 1812: 48779 not marked as hateful sentences remaining
# Year: 1890: 1069411 not marked as hateful sentences remaining
# Year: 1994: 2039 not marked as hateful sentences remaining
# Year: 1982: 3569 not marked as hateful sentences remaining
# Year: 1876: 673629 not marked as hateful sentences remaining
# Year: 1961: 94409 not marked as hateful sentences remaining
# Year: 1934: 78944 not marked as hateful sentences remaining
# Year: 1822: 58920 not marked as hateful sentences remaining
# Year: 1818: 163442 not marked as hateful sentences remaining
# Year: 1761: 1506 not marked as hateful sentences remaining
# Year: 1788: 28845 not marked as hateful sentences remaining
# Year: 1917: 1851456 not marked as hateful sentences remaining
# Year: 1992: 3532 not marked as hateful sentences remaining
# Year: 1845: 209713 not marked as hateful sentences remaining
# Year: 1797: 14548 not marked as hateful sentences remaining
# Year: 1758: 156 not marked as hateful sentences remaining
# Year: 1883: 603506 not marked as hateful sentences remaining
# Year: 1933: 100229 not marked as hateful sentences remaining
# Year: 1769: 16696 not marked as hateful sentences remaining
# Year: 1978: 4509 not marked as hateful sentences remaining
# Year: 1796: 70276 not marked as hateful sentences remaining
# Year: 1922: 2722469 not marked as hateful sentences remaining
# Year: 1806: 12719 not marked as hateful sentences remaining
# Year: 1984: 621 not marked as hateful sentences remaining
# Year: 1786: 42818 not marked as hateful sentences remaining
# Year: 1866: 430052 not marked as hateful sentences remaining
# Year: 1850: 420628 not marked as hateful sentences remaining
# Year: 1759: 49392 not marked as hateful sentences remaining
# Year: 1990: 489 not marked as hateful sentences remaining
# Retain set saved to /mnt/c/Users/larsj/hate_sents_2/Perspective/Datasets/pg_books_retain_set_0_7.jsonl
